# %% [markdown]
# <p style="border: 1px solid #e7692c; border-left: 15px solid #e7692c; padding: 10px; text-align:justify;">
#     <strong style="color: #e7692c">Tip.</strong> <a style="color: #000000;" href="https://nbviewer.jupyter.org/github/PacktPublishing/Hands-On-Computer-Vision-with-TensorFlow-2/blob/master/Chapter09/ch9_nb3_train_model.ipynb" title="View with Jupyter Online">Click here to view this notebook on <code>nbviewer.jupyter.org</code></a>.
#     <br/>These notebooks are better read there, as Github default viewer ignores some of the formatting and interactive content.
#     </p>

# %% [markdown]
# <table style="font-size: 1em; padding: 0; margin: 0;">
#     <tr style="vertical-align: top; padding: 0; margin: 0;background-color: #ffffff">
#         <td style="vertical-align: top; padding: 0; margin: 0; padding-right: 15px;">
#     <p style="background: #363636; color:#ffffff; text-align:justify; padding: 10px 25px;">
#         <strong style="font-size: 1.0em;"><span style="font-size: 1.2em;"><span style="color: #e7692c;">Hands-on</span> Computer Vision with TensorFlow 2</span><br/>by <em>Eliot Andres</em> & <em>Benjamin Planche</em> (Packt Pub.)</strong><br/><br/>
#         <strong>> Chapter 9: Performance and running on mobile</strong><br/>
#     </p>
#
# <h1 style="width: 100%; text-align: left; padding: 0px 25px;"><small style="color: #e7692c;">Notebook 3:</small><br/>Training a model and converting it for mobile devices</h1>
# <br/>
# <p style="border-left: 15px solid #363636; text-align:justify; padding: 0 10px;">
#     In this chapter, we covered how to convert and run a model on mobile.
# <br/><br/>
#     This notebooks trains a model to recognize face expressions and converts it to CoreML, TFLite and TensorFlow.js
# </p>
# <br/>
#
# <p style="border-left: 15px solid #363636; text-align:justify; padding: 0 10px;">
#     <strong> Requirements </strong>
# <br/><br/>
#     To run this notebook, you need to download the <a href="https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge/data">FER dataset</a> and extract it. When done, change the `BASE_PATH` variable to point to the dataset folder.
# </p>
# <br/>
# <p style="border-left: 15px solid #e7692c; padding: 0 10px; text-align:justify;">
#     <strong style="color: #e7692c;">Tip.</strong> The notebooks shared on this git repository illustrate some notions from the book "<em><strong>Hands-on Computer Vision with TensorFlow 2</strong></em>" written by Eliot Andres and Benjamin Planche, published by Packt. If you enjoyed the insights shared here, <a href="https://www.amazon.com/Hands-Computer-Vision-TensorFlow-processing/dp/1788830644" title="Learn more about the book!"><strong>please consider acquiring the book!</strong></a>
# <br/><br/>
# The book provides further guidance for those eager to learn about computer vision and to harness the power of TensorFlow 2 and Keras to build efficient recognition systems for object detection, segmentation, video processing, smartphone applications, and more.</p>
#         </td>
#         <td style="vertical-align: top; padding: 0; margin: 0; width: 280px;">
#     <a href="https://www.amazon.com/Hands-Computer-Vision-TensorFlow-processing/dp/1788830644" title="Learn more about the book!" target="_blank">
#         <img src="../banner_images/book_cover.png" width=280>
#     </a>
#     <p style="background: #e7692c; color:#ffffff; padding: 10px; text-align:justify;"><strong>Leverage deep learning to create powerful image processing apps with TensorFlow 2 and Keras. <br/></strong>Get the book for more insights!</p>
#     <ul style="height: 32px; white-space: nowrap; text-align: center; margin: 0px; padding: 0px; padding-top: 10px;">
#     <li style="display: block;height: 100%;float: left;vertical-align: middle;margin: 0 25px 10px;padding: 0px;">
#         <a href="https://www.amazon.com/Hands-Computer-Vision-TensorFlow-processing/dp/1788830644" title="Get the book on Amazon (paperback or Kindle version)!" target="_blank">
#         <img style="vertical-align: middle; max-width: 72px; max-height: 32px;" src="../banner_images/logo_amazon.png" width="75px">
#         </a>
#     </li>
#     <li style="display: inline-block;height: 100%;vertical-align: middle;float: right;margin: -5px 25px 10px;padding: 0px;">
#         <a href="https://www.packtpub.com/application-development/hands-computer-vision-tensorflow-2" title="Get your Packt book (paperback, PDF, ePUB, or MOBI version)!" target="_blank">
#         <img style="vertical-align: middle; max-width: 72px; max-height: 32px;" src="../banner_images/logo_packt.png" width="75px">
#         </a>
#     </li>
#     </ul>
#         </td>
#         </tr>
#         </table>

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.layers import Input
from sklearn.model_selection import train_test_split
import pandas as pd
import cv2
import numpy as np
import tensorflow as tf

tf.__version__
# Out:
# '2.0.0-dev20190428'

# %% [markdown]
# ## Set constants and parameters

# %%
# Download data here: https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge/data
DATASET_PATH = '../data/fer2013/fer2013.csv'

IMAGE_SIZE = (48, 48)
INPUT_SHAPE = IMAGE_SIZE + (1,)
EMOTIONS = ["angry", "disgust", "scared",
            "happy", "sad", "surprised", "neutral"]
CALLBACK_PATIENCE = 50
BATCH_SIZE = 32
NUM_EPOCHS = 50
VALIDATION_SPLIT = .2
NUM_CLASSES = len(EMOTIONS)
L2_REGULARIZATION = 0.01

# %% [markdown]
# ## Build the model

# %%
input_tensor = Input(shape=INPUT_SHAPE)
model = MobileNet(input_tensor=input_tensor, alpha=1.0,
                    include_top=False, weights=None)

output = tf.keras.layers.Reshape((1024,))(model.output)
output = tf.keras.layers.Dense(7, activation='softmax')(output)
model = tf.keras.Model(model.input, output)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 48, 48, 1)]       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 49, 49, 1)         0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 24, 24, 32)        288
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 24, 24, 32)        128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 24, 24, 32)        0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 24, 24, 32)        288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 24, 24, 32)        128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 24, 24, 32)        0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 24, 24, 64)        2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 24, 24, 64)        256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 24, 24, 64)        0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 25, 25, 64)        0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 12, 12, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 12, 12, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 12, 12, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 12, 12, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 12, 12, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 12, 12, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 12, 12, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 12, 12, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 12, 12, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 12, 12, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 12, 12, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 12, 12, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 13, 13, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 6, 6, 128)         1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 6, 6, 128)         512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 6, 6, 128)         0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 6, 6, 256)         32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 6, 6, 256)         0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 6, 6, 256)         2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 6, 6, 256)         0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 6, 6, 256)         65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 6, 6, 256)         0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 7, 7, 256)         0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 3, 3, 256)         2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 3, 3, 256)         1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 3, 3, 256)         0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 3, 3, 512)         131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 3, 3, 512)         4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 3, 3, 512)         262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 3, 3, 512)         4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 3, 3, 512)         262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 3, 3, 512)         4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 3, 3, 512)         262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 3, 3, 512)         4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 3, 3, 512)         262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 3, 3, 512)         4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 3, 3, 512)         262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 1, 1, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 1, 1, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 1, 1, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 1, 1, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 1, 1, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 1, 1, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 1, 1, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 1, 1, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 1, 1, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 1, 1, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 1, 1, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 1, 1, 1024)        0
# _________________________________________________________________
# reshape (Reshape)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 7)                 7175
# =================================================================
# Total params: 3,235,463
# Trainable params: 3,213,575
# Non-trainable params: 21,888
# _________________________________________________________________

# %% [markdown]
# ## Load data

# %%
def load_fer2013():
    data = pd.read_csv(DATASET_PATH)
    pixels = data['pixels'].tolist()
    width, height = 48, 48
    faces = []
    for pixel_sequence in pixels:
        face = [int(pixel) for pixel in pixel_sequence.split(' ')]
        face = np.asarray(face).reshape(width, height)
        face = cv2.resize(face.astype('uint8'), IMAGE_SIZE)
        faces.append(face.astype('float32'))
    faces = np.asarray(faces)
    faces = np.expand_dims(faces, -1)
    emotions = pd.get_dummies(data['emotion']).values
    return faces, emotions

def preprocess_input(x, v2=True):
    x = x.astype('float32')
    x = x / 255.0
    x = x - 0.5
    x = x * 2.0
    return x

data_generator = ImageDataGenerator(
    featurewise_center=False,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=.1,
    horizontal_flip=True)

# loading dataset
faces, emotions = load_fer2013()
faces = preprocess_input(faces)

# %% [markdown]
# ## Train model

# %%
regularization = tf.keras.regularizers.l2(L2_REGULARIZATION)

early_stop = EarlyStopping('val_loss', patience=CALLBACK_PATIENCE)
reduce_lr = ReduceLROnPlateau(
    'val_loss', factor=0.1, patience=int(CALLBACK_PATIENCE/4), verbose=1)
tensorboard = TensorBoard('./logs')
callbacks = [early_stop, reduce_lr, tensorboard]

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
xtrain, xtest, ytrain, ytest = train_test_split(faces, emotions, test_size=0.2)

model.fit_generator(data_generator.flow(xtrain, ytrain, BATCH_SIZE),
                    steps_per_epoch=len(xtrain) / BATCH_SIZE,
                    epochs=NUM_EPOCHS, verbose=1, callbacks=callbacks,
                    validation_data=(xtest, ytest))
# Out:
# Epoch 1/50
# 898/897 [==============================] - 37s 41ms/step - loss: 1.8936 - accuracy: 0.2319 - val_loss: 1.9043 - val_accuracy: 0.2530
# Epoch 2/50
# 898/897 [==============================] - 21s 24ms/step - loss: 1.8200 - accuracy: 0.2649 - val_loss: 1.7767 - val_accuracy: 0.2768
# Epoch 3/50
# 898/897 [==============================] - 21s 24ms/step - loss: 1.7820 - accuracy: 0.2988 - val_loss: 1.8422 - val_accuracy: 0.3034
# Epoch 4/50
# 898/897 [==============================] - 21s 24ms/step - loss: 1.7192 - accuracy: 0.3265 - val_loss: 1.9029 - val_accuracy: 0.2336
# Epoch 5/50
# 898/897 [==============================] - 21s 24ms/step - loss: 1.6862 - accuracy: 0.3394 - val_loss: 1.6631 - val_accuracy: 0.3416
# Epoch 6/50
# 898/897 [==============================] - 21s 24ms/step - loss: 1.6721 - accuracy: 0.3502 - val_loss: 1.6184 - val_accuracy: 0.3767
# Epoch 7/50
# 898/897 [==============================] - 21s 24ms/step - loss: 1.5909 - accuracy: 0.3841 - val_loss: 1.6010 - val_accuracy: 0.3938
# Epoch 8/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.5573 - accuracy: 0.3980 - val_loss: 1.4983 - val_accuracy: 0.4234
# Epoch 9/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.5219 - accuracy: 0.4153 - val_loss: 1.5643 - val_accuracy: 0.3969
# Epoch 10/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.4756 - accuracy: 0.4304 - val_loss: 1.3906 - val_accuracy: 0.4673
# Epoch 11/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.4226 - accuracy: 0.4564 - val_loss: 1.3008 - val_accuracy: 0.4996
# Epoch 12/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.3726 - accuracy: 0.4771 - val_loss: 1.3063 - val_accuracy: 0.4990
# Epoch 13/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.3459 - accuracy: 0.4913 - val_loss: 1.4578 - val_accuracy: 0.4411
# Epoch 14/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.3270 - accuracy: 0.4988 - val_loss: 1.4089 - val_accuracy: 0.4536
# Epoch 15/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.2788 - accuracy: 0.5149 - val_loss: 1.2692 - val_accuracy: 0.5210
# Epoch 16/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.2438 - accuracy: 0.5274 - val_loss: 1.1983 - val_accuracy: 0.5507
# Epoch 17/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.2278 - accuracy: 0.5352 - val_loss: 1.2243 - val_accuracy: 0.5352
# Epoch 18/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.2062 - accuracy: 0.5438 - val_loss: 1.1963 - val_accuracy: 0.5534
# Epoch 19/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.1937 - accuracy: 0.5510 - val_loss: 1.2240 - val_accuracy: 0.5391
# Epoch 20/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.1781 - accuracy: 0.5520 - val_loss: 1.1659 - val_accuracy: 0.5614
# Epoch 21/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.1829 - accuracy: 0.5578 - val_loss: 1.1816 - val_accuracy: 0.5613
# Epoch 22/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.1432 - accuracy: 0.5717 - val_loss: 1.1201 - val_accuracy: 0.5730
# Epoch 23/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.1655 - accuracy: 0.5610 - val_loss: 1.1035 - val_accuracy: 0.5800
# Epoch 24/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.1140 - accuracy: 0.5810 - val_loss: 1.0714 - val_accuracy: 0.5965
# Epoch 25/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.1056 - accuracy: 0.5801 - val_loss: 1.0932 - val_accuracy: 0.5828
# Epoch 26/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.0887 - accuracy: 0.5920 - val_loss: 1.0800 - val_accuracy: 0.5946
# Epoch 27/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.0832 - accuracy: 0.5963 - val_loss: 1.1731 - val_accuracy: 0.5577
# Epoch 28/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.0701 - accuracy: 0.5991 - val_loss: 1.0919 - val_accuracy: 0.5949
# Epoch 29/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.0593 - accuracy: 0.6032 - val_loss: 1.0946 - val_accuracy: 0.5879
# Epoch 30/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.0639 - accuracy: 0.6013 - val_loss: 1.1607 - val_accuracy: 0.5564
# Epoch 31/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.0415 - accuracy: 0.6091 - val_loss: 1.0763 - val_accuracy: 0.5918
# Epoch 32/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.0785 - accuracy: 0.5972 - val_loss: 1.0458 - val_accuracy: 0.6039
# Epoch 33/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.0312 - accuracy: 0.6121 - val_loss: 1.0386 - val_accuracy: 0.6053
# Epoch 34/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.0193 - accuracy: 0.6193 - val_loss: 1.0594 - val_accuracy: 0.5991
# Epoch 35/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.0303 - accuracy: 0.6160 - val_loss: 1.0548 - val_accuracy: 0.6057
# Epoch 36/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.0091 - accuracy: 0.6236 - val_loss: 1.0402 - val_accuracy: 0.6115
# Epoch 37/50
# 898/897 [==============================] - 22s 24ms/step - loss: 0.9995 - accuracy: 0.6245 - val_loss: 1.0429 - val_accuracy: 0.6050
# Epoch 38/50
# 898/897 [==============================] - 22s 24ms/step - loss: 1.0011 - accuracy: 0.6283 - val_loss: 1.0650 - val_accuracy: 0.5956
# Epoch 39/50
# 898/897 [==============================] - 22s 24ms/step - loss: 0.9881 - accuracy: 0.6300 - val_loss: 1.0668 - val_accuracy: 0.6048
# Epoch 40/50
# 898/897 [==============================] - 22s 24ms/step - loss: 0.9707 - accuracy: 0.6382 - val_loss: 1.0477 - val_accuracy: 0.6076
# Epoch 41/50
# 898/897 [==============================] - 22s 24ms/step - loss: 0.9635 - accuracy: 0.6387 - val_loss: 1.0177 - val_accuracy: 0.6234
# Epoch 42/50
# 898/897 [==============================] - 22s 24ms/step - loss: 0.9649 - accuracy: 0.6399 - val_loss: 1.0189 - val_accuracy: 0.6227
# Epoch 43/50
# 898/897 [==============================] - 22s 24ms/step - loss: 0.9596 - accuracy: 0.6407 - val_loss: 1.0014 - val_accuracy: 0.6271
# Epoch 44/50
# 898/897 [==============================] - 22s 24ms/step - loss: 0.9500 - accuracy: 0.6433 - val_loss: 1.0129 - val_accuracy: 0.6284
# Epoch 45/50
# 898/897 [==============================] - 22s 24ms/step - loss: 0.9321 - accuracy: 0.6527 - val_loss: 1.0122 - val_accuracy: 0.6193
# Epoch 46/50
# 898/897 [==============================] - 22s 24ms/step - loss: 0.9544 - accuracy: 0.6438 - val_loss: 1.0115 - val_accuracy: 0.6241
# Epoch 47/50
# 898/897 [==============================] - 22s 24ms/step - loss: 0.9465 - accuracy: 0.6453 - val_loss: 1.0028 - val_accuracy: 0.6220
# Epoch 48/50
# 898/897 [==============================] - 22s 24ms/step - loss: 0.9173 - accuracy: 0.6576 - val_loss: 1.0142 - val_accuracy: 0.6262
# Epoch 49/50
# 898/897 [==============================] - 22s 24ms/step - loss: 0.9120 - accuracy: 0.6603 - val_loss: 1.0119 - val_accuracy: 0.6296
# Epoch 50/50
# 898/897 [==============================] - 22s 24ms/step - loss: 0.9025 - accuracy: 0.6608 - val_loss: 1.0203 - val_accuracy: 0.6308

# %% [markdown]
# ## Convert to CoreML

# %%
import tfcoreml as tf_converter
from tensorflow.python.keras.callbacks import TensorBoard
from tensorflow.python.saved_model import tag_constants
from tensorflow.python.tools import freeze_graph
input_saved_model_dir = "./saved_model"

tf.keras.experimental.export_saved_model(
    model, saved_model_path=input_saved_model_dir, serving_only=False)


output_node_name = 'dense/Softmax'
input_binary = False
input_saver_def_path = False
restore_op_name = None
filename_tensor_name = None
clear_devices = True
input_meta_graph = False
checkpoint_path = None
input_graph_filename = None
saved_model_tags = tag_constants.SERVING


freeze_graph.freeze_graph(input_graph_filename, input_saver_def_path,
                          input_binary, checkpoint_path, output_node_name,
                          restore_op_name, filename_tensor_name,
                          'frozen_model.pb', clear_devices, "", "", "",
                          input_meta_graph, input_saved_model_dir,
                          saved_model_tags)


tf_converter.convert('frozen_model.pb',
                     'mobilenet.mlmodel',
                     class_labels=EMOTIONS,
                     image_input_names=['input_1:0'],
                     output_feature_names=[output_node_name + ':0'],
                     red_bias=-1,
                     green_bias=-1,
                     blue_bias=-1,
                     image_scale=1/127.5,
                     is_bgr=False)
# Out:
# W0526 16:34:32.567987 140384533387008 tf_logging.py:161] Export includes no default signature!
# W0526 16:34:35.210698 140384533387008 tf_logging.py:161] Export includes no default signature!
# Loading the TF graph...
# Graph Loaded.
# Now finding ops in the TF graph that can be dropped for inference
# Collecting all the 'Const' ops from the graph, by running it....
# Done.
# Now starting translation to CoreML graph.
# Automatic shape interpretation succeeded for input blob input_1:0
# 1/377: Analysing op name: dense/bias ( type:  Const )
# 2/377: Analysing op name: dense/BiasAdd/ReadVariableOp ( type:  Identity )
# 3/377: Analysing op name: dense/kernel ( type:  Const )
# 4/377: Analysing op name: dense/MatMul/ReadVariableOp ( type:  Identity )
# 5/377: Analysing op name: reshape/Reshape/shape/1 ( type:  Const )
# 6/377: Analysing op name: reshape/strided_slice/stack_2 ( type:  Const )
# 7/377: Analysing op name: reshape/strided_slice/stack_1 ( type:  Const )
# 8/377: Analysing op name: reshape/strided_slice/stack ( type:  Const )
# 9/377: Analysing op name: conv_pw_13_bn/moving_variance ( type:  Const )
# 10/377: Analysing op name: conv_pw_13_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 11/377: Analysing op name: conv_pw_13_bn/moving_mean ( type:  Const )
# 12/377: Analysing op name: conv_pw_13_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 13/377: Analysing op name: conv_pw_13_bn/beta ( type:  Const )
# 14/377: Analysing op name: conv_pw_13_bn/ReadVariableOp_1 ( type:  Identity )
# 15/377: Analysing op name: conv_pw_13_bn/gamma ( type:  Const )
# 16/377: Analysing op name: conv_pw_13_bn/ReadVariableOp ( type:  Identity )
# 17/377: Analysing op name: conv_pw_13/kernel ( type:  Const )
# 18/377: Analysing op name: conv_pw_13/Conv2D/ReadVariableOp ( type:  Identity )
# 19/377: Analysing op name: conv_dw_13_bn/moving_variance ( type:  Const )
# 20/377: Analysing op name: conv_dw_13_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 21/377: Analysing op name: conv_dw_13_bn/moving_mean ( type:  Const )
# 22/377: Analysing op name: conv_dw_13_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 23/377: Analysing op name: conv_dw_13_bn/beta ( type:  Const )
# 24/377: Analysing op name: conv_dw_13_bn/ReadVariableOp_1 ( type:  Identity )
# 25/377: Analysing op name: conv_dw_13_bn/gamma ( type:  Const )
# 26/377: Analysing op name: conv_dw_13_bn/ReadVariableOp ( type:  Identity )
# 27/377: Analysing op name: conv_dw_13/depthwise_kernel ( type:  Const )
# 28/377: Analysing op name: conv_dw_13/depthwise/ReadVariableOp ( type:  Identity )
# 29/377: Analysing op name: conv_pw_12_bn/moving_variance ( type:  Const )
# 30/377: Analysing op name: conv_pw_12_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 31/377: Analysing op name: conv_pw_12_bn/moving_mean ( type:  Const )
# 32/377: Analysing op name: conv_pw_12_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 33/377: Analysing op name: conv_pw_12_bn/beta ( type:  Const )
# 34/377: Analysing op name: conv_pw_12_bn/ReadVariableOp_1 ( type:  Identity )
# 35/377: Analysing op name: conv_pw_12_bn/gamma ( type:  Const )
# 36/377: Analysing op name: conv_pw_12_bn/ReadVariableOp ( type:  Identity )
# 37/377: Analysing op name: conv_pw_12/kernel ( type:  Const )
# 38/377: Analysing op name: conv_pw_12/Conv2D/ReadVariableOp ( type:  Identity )
# 39/377: Analysing op name: conv_dw_12_bn/moving_variance ( type:  Const )
# 40/377: Analysing op name: conv_dw_12_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 41/377: Analysing op name: conv_dw_12_bn/moving_mean ( type:  Const )
# 42/377: Analysing op name: conv_dw_12_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 43/377: Analysing op name: conv_dw_12_bn/beta ( type:  Const )
# 44/377: Analysing op name: conv_dw_12_bn/ReadVariableOp_1 ( type:  Identity )
# 45/377: Analysing op name: conv_dw_12_bn/gamma ( type:  Const )
# 46/377: Analysing op name: conv_dw_12_bn/ReadVariableOp ( type:  Identity )
# 47/377: Analysing op name: conv_dw_12/depthwise_kernel ( type:  Const )
# 48/377: Analysing op name: conv_dw_12/depthwise/ReadVariableOp ( type:  Identity )
# 49/377: Analysing op name: conv_pad_12/Pad/paddings ( type:  Const )
# 50/377: Analysing op name: conv_pw_11_bn/moving_variance ( type:  Const )
# 51/377: Analysing op name: conv_pw_11_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 52/377: Analysing op name: conv_pw_11_bn/moving_mean ( type:  Const )
# 53/377: Analysing op name: conv_pw_11_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 54/377: Analysing op name: conv_pw_11_bn/beta ( type:  Const )
# 55/377: Analysing op name: conv_pw_11_bn/ReadVariableOp_1 ( type:  Identity )
# 56/377: Analysing op name: conv_pw_11_bn/gamma ( type:  Const )
# 57/377: Analysing op name: conv_pw_11_bn/ReadVariableOp ( type:  Identity )
# 58/377: Analysing op name: conv_pw_11/kernel ( type:  Const )
# 59/377: Analysing op name: conv_pw_11/Conv2D/ReadVariableOp ( type:  Identity )
# 60/377: Analysing op name: conv_dw_11_bn/moving_variance ( type:  Const )
# 61/377: Analysing op name: conv_dw_11_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 62/377: Analysing op name: conv_dw_11_bn/moving_mean ( type:  Const )
# 63/377: Analysing op name: conv_dw_11_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 64/377: Analysing op name: conv_dw_11_bn/beta ( type:  Const )
# 65/377: Analysing op name: conv_dw_11_bn/ReadVariableOp_1 ( type:  Identity )
# 66/377: Analysing op name: conv_dw_11_bn/gamma ( type:  Const )
# 67/377: Analysing op name: conv_dw_11_bn/ReadVariableOp ( type:  Identity )
# 68/377: Analysing op name: conv_dw_11/depthwise_kernel ( type:  Const )
# 69/377: Analysing op name: conv_dw_11/depthwise/ReadVariableOp ( type:  Identity )
# 70/377: Analysing op name: conv_pw_10_bn/moving_variance ( type:  Const )
# 71/377: Analysing op name: conv_pw_10_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 72/377: Analysing op name: conv_pw_10_bn/moving_mean ( type:  Const )
# 73/377: Analysing op name: conv_pw_10_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 74/377: Analysing op name: conv_pw_10_bn/beta ( type:  Const )
# 75/377: Analysing op name: conv_pw_10_bn/ReadVariableOp_1 ( type:  Identity )
# 76/377: Analysing op name: conv_pw_10_bn/gamma ( type:  Const )
# 77/377: Analysing op name: conv_pw_10_bn/ReadVariableOp ( type:  Identity )
# 78/377: Analysing op name: conv_pw_10/kernel ( type:  Const )
# 79/377: Analysing op name: conv_pw_10/Conv2D/ReadVariableOp ( type:  Identity )
# 80/377: Analysing op name: conv_dw_10_bn/moving_variance ( type:  Const )
# 81/377: Analysing op name: conv_dw_10_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 82/377: Analysing op name: conv_dw_10_bn/moving_mean ( type:  Const )
# 83/377: Analysing op name: conv_dw_10_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 84/377: Analysing op name: conv_dw_10_bn/beta ( type:  Const )
# 85/377: Analysing op name: conv_dw_10_bn/ReadVariableOp_1 ( type:  Identity )
# 86/377: Analysing op name: conv_dw_10_bn/gamma ( type:  Const )
# 87/377: Analysing op name: conv_dw_10_bn/ReadVariableOp ( type:  Identity )
# 88/377: Analysing op name: conv_dw_10/depthwise_kernel ( type:  Const )
# 89/377: Analysing op name: conv_dw_10/depthwise/ReadVariableOp ( type:  Identity )
# 90/377: Analysing op name: conv_pw_9_bn/moving_variance ( type:  Const )
# 91/377: Analysing op name: conv_pw_9_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 92/377: Analysing op name: conv_pw_9_bn/moving_mean ( type:  Const )
# 93/377: Analysing op name: conv_pw_9_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 94/377: Analysing op name: conv_pw_9_bn/beta ( type:  Const )
# 95/377: Analysing op name: conv_pw_9_bn/ReadVariableOp_1 ( type:  Identity )
# 96/377: Analysing op name: conv_pw_9_bn/gamma ( type:  Const )
# 97/377: Analysing op name: conv_pw_9_bn/ReadVariableOp ( type:  Identity )
# 98/377: Analysing op name: conv_pw_9/kernel ( type:  Const )
# 99/377: Analysing op name: conv_pw_9/Conv2D/ReadVariableOp ( type:  Identity )
# 100/377: Analysing op name: conv_dw_9_bn/moving_variance ( type:  Const )
# 101/377: Analysing op name: conv_dw_9_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 102/377: Analysing op name: conv_dw_9_bn/moving_mean ( type:  Const )
# 103/377: Analysing op name: conv_dw_9_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 104/377: Analysing op name: conv_dw_9_bn/beta ( type:  Const )
# 105/377: Analysing op name: conv_dw_9_bn/ReadVariableOp_1 ( type:  Identity )
# 106/377: Analysing op name: conv_dw_9_bn/gamma ( type:  Const )
# 107/377: Analysing op name: conv_dw_9_bn/ReadVariableOp ( type:  Identity )
# 108/377: Analysing op name: conv_dw_9/depthwise_kernel ( type:  Const )
# 109/377: Analysing op name: conv_dw_9/depthwise/ReadVariableOp ( type:  Identity )
# 110/377: Analysing op name: conv_pw_8_bn/moving_variance ( type:  Const )
# 111/377: Analysing op name: conv_pw_8_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 112/377: Analysing op name: conv_pw_8_bn/moving_mean ( type:  Const )
# 113/377: Analysing op name: conv_pw_8_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 114/377: Analysing op name: conv_pw_8_bn/beta ( type:  Const )
# 115/377: Analysing op name: conv_pw_8_bn/ReadVariableOp_1 ( type:  Identity )
# 116/377: Analysing op name: conv_pw_8_bn/gamma ( type:  Const )
# 117/377: Analysing op name: conv_pw_8_bn/ReadVariableOp ( type:  Identity )
# 118/377: Analysing op name: conv_pw_8/kernel ( type:  Const )
# 119/377: Analysing op name: conv_pw_8/Conv2D/ReadVariableOp ( type:  Identity )
# 120/377: Analysing op name: conv_dw_8_bn/moving_variance ( type:  Const )
# 121/377: Analysing op name: conv_dw_8_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 122/377: Analysing op name: conv_dw_8_bn/moving_mean ( type:  Const )
# 123/377: Analysing op name: conv_dw_8_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 124/377: Analysing op name: conv_dw_8_bn/beta ( type:  Const )
# 125/377: Analysing op name: conv_dw_8_bn/ReadVariableOp_1 ( type:  Identity )
# 126/377: Analysing op name: conv_dw_8_bn/gamma ( type:  Const )
# 127/377: Analysing op name: conv_dw_8_bn/ReadVariableOp ( type:  Identity )
# 128/377: Analysing op name: conv_dw_8/depthwise_kernel ( type:  Const )
# 129/377: Analysing op name: conv_dw_8/depthwise/ReadVariableOp ( type:  Identity )
# 130/377: Analysing op name: conv_pw_7_bn/moving_variance ( type:  Const )
# 131/377: Analysing op name: conv_pw_7_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 132/377: Analysing op name: conv_pw_7_bn/moving_mean ( type:  Const )
# 133/377: Analysing op name: conv_pw_7_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 134/377: Analysing op name: conv_pw_7_bn/beta ( type:  Const )
# 135/377: Analysing op name: conv_pw_7_bn/ReadVariableOp_1 ( type:  Identity )
# 136/377: Analysing op name: conv_pw_7_bn/gamma ( type:  Const )
# 137/377: Analysing op name: conv_pw_7_bn/ReadVariableOp ( type:  Identity )
# 138/377: Analysing op name: conv_pw_7/kernel ( type:  Const )
# 139/377: Analysing op name: conv_pw_7/Conv2D/ReadVariableOp ( type:  Identity )
# 140/377: Analysing op name: conv_dw_7_bn/moving_variance ( type:  Const )
# 141/377: Analysing op name: conv_dw_7_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 142/377: Analysing op name: conv_dw_7_bn/moving_mean ( type:  Const )
# 143/377: Analysing op name: conv_dw_7_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 144/377: Analysing op name: conv_dw_7_bn/beta ( type:  Const )
# 145/377: Analysing op name: conv_dw_7_bn/ReadVariableOp_1 ( type:  Identity )
# 146/377: Analysing op name: conv_dw_7_bn/gamma ( type:  Const )
# 147/377: Analysing op name: conv_dw_7_bn/ReadVariableOp ( type:  Identity )
# 148/377: Analysing op name: conv_dw_7/depthwise_kernel ( type:  Const )
# 149/377: Analysing op name: conv_dw_7/depthwise/ReadVariableOp ( type:  Identity )
# 150/377: Analysing op name: conv_pw_6_bn/moving_variance ( type:  Const )
# 151/377: Analysing op name: conv_pw_6_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 152/377: Analysing op name: conv_pw_6_bn/moving_mean ( type:  Const )
# 153/377: Analysing op name: conv_pw_6_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 154/377: Analysing op name: conv_pw_6_bn/beta ( type:  Const )
# 155/377: Analysing op name: conv_pw_6_bn/ReadVariableOp_1 ( type:  Identity )
# 156/377: Analysing op name: conv_pw_6_bn/gamma ( type:  Const )
# 157/377: Analysing op name: conv_pw_6_bn/ReadVariableOp ( type:  Identity )
# 158/377: Analysing op name: conv_pw_6/kernel ( type:  Const )
# 159/377: Analysing op name: conv_pw_6/Conv2D/ReadVariableOp ( type:  Identity )
# 160/377: Analysing op name: conv_dw_6_bn/moving_variance ( type:  Const )
# 161/377: Analysing op name: conv_dw_6_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 162/377: Analysing op name: conv_dw_6_bn/moving_mean ( type:  Const )
# 163/377: Analysing op name: conv_dw_6_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 164/377: Analysing op name: conv_dw_6_bn/beta ( type:  Const )
# 165/377: Analysing op name: conv_dw_6_bn/ReadVariableOp_1 ( type:  Identity )
# 166/377: Analysing op name: conv_dw_6_bn/gamma ( type:  Const )
# 167/377: Analysing op name: conv_dw_6_bn/ReadVariableOp ( type:  Identity )
# 168/377: Analysing op name: conv_dw_6/depthwise_kernel ( type:  Const )
# 169/377: Analysing op name: conv_dw_6/depthwise/ReadVariableOp ( type:  Identity )
# 170/377: Analysing op name: conv_pad_6/Pad/paddings ( type:  Const )
# 171/377: Analysing op name: conv_pw_5_bn/moving_variance ( type:  Const )
# 172/377: Analysing op name: conv_pw_5_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 173/377: Analysing op name: conv_pw_5_bn/moving_mean ( type:  Const )
# 174/377: Analysing op name: conv_pw_5_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 175/377: Analysing op name: conv_pw_5_bn/beta ( type:  Const )
# 176/377: Analysing op name: conv_pw_5_bn/ReadVariableOp_1 ( type:  Identity )
# 177/377: Analysing op name: conv_pw_5_bn/gamma ( type:  Const )
# 178/377: Analysing op name: conv_pw_5_bn/ReadVariableOp ( type:  Identity )
# 179/377: Analysing op name: conv_pw_5/kernel ( type:  Const )
# 180/377: Analysing op name: conv_pw_5/Conv2D/ReadVariableOp ( type:  Identity )
# 181/377: Analysing op name: conv_dw_5_bn/moving_variance ( type:  Const )
# 182/377: Analysing op name: conv_dw_5_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 183/377: Analysing op name: conv_dw_5_bn/moving_mean ( type:  Const )
# 184/377: Analysing op name: conv_dw_5_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 185/377: Analysing op name: conv_dw_5_bn/beta ( type:  Const )
# 186/377: Analysing op name: conv_dw_5_bn/ReadVariableOp_1 ( type:  Identity )
# 187/377: Analysing op name: conv_dw_5_bn/gamma ( type:  Const )
# 188/377: Analysing op name: conv_dw_5_bn/ReadVariableOp ( type:  Identity )
# 189/377: Analysing op name: conv_dw_5/depthwise_kernel ( type:  Const )
# 190/377: Analysing op name: conv_dw_5/depthwise/ReadVariableOp ( type:  Identity )
# 191/377: Analysing op name: conv_pw_4_bn/moving_variance ( type:  Const )
# 192/377: Analysing op name: conv_pw_4_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 193/377: Analysing op name: conv_pw_4_bn/moving_mean ( type:  Const )
# 194/377: Analysing op name: conv_pw_4_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 195/377: Analysing op name: conv_pw_4_bn/beta ( type:  Const )
# 196/377: Analysing op name: conv_pw_4_bn/ReadVariableOp_1 ( type:  Identity )
# 197/377: Analysing op name: conv_pw_4_bn/gamma ( type:  Const )
# 198/377: Analysing op name: conv_pw_4_bn/ReadVariableOp ( type:  Identity )
# 199/377: Analysing op name: conv_pw_4/kernel ( type:  Const )
# 200/377: Analysing op name: conv_pw_4/Conv2D/ReadVariableOp ( type:  Identity )
# 201/377: Analysing op name: conv_dw_4_bn/moving_variance ( type:  Const )
# 202/377: Analysing op name: conv_dw_4_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 203/377: Analysing op name: conv_dw_4_bn/moving_mean ( type:  Const )
# 204/377: Analysing op name: conv_dw_4_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 205/377: Analysing op name: conv_dw_4_bn/beta ( type:  Const )
# 206/377: Analysing op name: conv_dw_4_bn/ReadVariableOp_1 ( type:  Identity )
# 207/377: Analysing op name: conv_dw_4_bn/gamma ( type:  Const )
# 208/377: Analysing op name: conv_dw_4_bn/ReadVariableOp ( type:  Identity )
# 209/377: Analysing op name: conv_dw_4/depthwise_kernel ( type:  Const )
# 210/377: Analysing op name: conv_dw_4/depthwise/ReadVariableOp ( type:  Identity )
# 211/377: Analysing op name: conv_pad_4/Pad/paddings ( type:  Const )
# 212/377: Analysing op name: conv_pw_3_bn/moving_variance ( type:  Const )
# 213/377: Analysing op name: conv_pw_3_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 214/377: Analysing op name: conv_pw_3_bn/moving_mean ( type:  Const )
# 215/377: Analysing op name: conv_pw_3_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 216/377: Analysing op name: conv_pw_3_bn/beta ( type:  Const )
# 217/377: Analysing op name: conv_pw_3_bn/ReadVariableOp_1 ( type:  Identity )
# 218/377: Analysing op name: conv_pw_3_bn/gamma ( type:  Const )
# 219/377: Analysing op name: conv_pw_3_bn/ReadVariableOp ( type:  Identity )
# 220/377: Analysing op name: conv_pw_3/kernel ( type:  Const )
# 221/377: Analysing op name: conv_pw_3/Conv2D/ReadVariableOp ( type:  Identity )
# 222/377: Analysing op name: conv_dw_3_bn/moving_variance ( type:  Const )
# 223/377: Analysing op name: conv_dw_3_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 224/377: Analysing op name: conv_dw_3_bn/moving_mean ( type:  Const )
# 225/377: Analysing op name: conv_dw_3_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 226/377: Analysing op name: conv_dw_3_bn/beta ( type:  Const )
# 227/377: Analysing op name: conv_dw_3_bn/ReadVariableOp_1 ( type:  Identity )
# 228/377: Analysing op name: conv_dw_3_bn/gamma ( type:  Const )
# 229/377: Analysing op name: conv_dw_3_bn/ReadVariableOp ( type:  Identity )
# 230/377: Analysing op name: conv_dw_3/depthwise_kernel ( type:  Const )
# 231/377: Analysing op name: conv_dw_3/depthwise/ReadVariableOp ( type:  Identity )
# 232/377: Analysing op name: conv_pw_2_bn/moving_variance ( type:  Const )
# 233/377: Analysing op name: conv_pw_2_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 234/377: Analysing op name: conv_pw_2_bn/moving_mean ( type:  Const )
# 235/377: Analysing op name: conv_pw_2_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 236/377: Analysing op name: conv_pw_2_bn/beta ( type:  Const )
# 237/377: Analysing op name: conv_pw_2_bn/ReadVariableOp_1 ( type:  Identity )
# 238/377: Analysing op name: conv_pw_2_bn/gamma ( type:  Const )
# 239/377: Analysing op name: conv_pw_2_bn/ReadVariableOp ( type:  Identity )
# 240/377: Analysing op name: conv_pw_2/kernel ( type:  Const )
# 241/377: Analysing op name: conv_pw_2/Conv2D/ReadVariableOp ( type:  Identity )
# 242/377: Analysing op name: conv_dw_2_bn/moving_variance ( type:  Const )
# 243/377: Analysing op name: conv_dw_2_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 244/377: Analysing op name: conv_dw_2_bn/moving_mean ( type:  Const )
# 245/377: Analysing op name: conv_dw_2_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 246/377: Analysing op name: conv_dw_2_bn/beta ( type:  Const )
# 247/377: Analysing op name: conv_dw_2_bn/ReadVariableOp_1 ( type:  Identity )
# 248/377: Analysing op name: conv_dw_2_bn/gamma ( type:  Const )
# 249/377: Analysing op name: conv_dw_2_bn/ReadVariableOp ( type:  Identity )
# 250/377: Analysing op name: conv_dw_2/depthwise_kernel ( type:  Const )
# 251/377: Analysing op name: conv_dw_2/depthwise/ReadVariableOp ( type:  Identity )
# 252/377: Analysing op name: conv_pad_2/Pad/paddings ( type:  Const )
# 253/377: Analysing op name: conv_pw_1_bn/moving_variance ( type:  Const )
# 254/377: Analysing op name: conv_pw_1_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 255/377: Analysing op name: conv_pw_1_bn/moving_mean ( type:  Const )
# 256/377: Analysing op name: conv_pw_1_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 257/377: Analysing op name: conv_pw_1_bn/beta ( type:  Const )
# 258/377: Analysing op name: conv_pw_1_bn/ReadVariableOp_1 ( type:  Identity )
# 259/377: Analysing op name: conv_pw_1_bn/gamma ( type:  Const )
# 260/377: Analysing op name: conv_pw_1_bn/ReadVariableOp ( type:  Identity )
# 261/377: Analysing op name: conv_pw_1/kernel ( type:  Const )
# 262/377: Analysing op name: conv_pw_1/Conv2D/ReadVariableOp ( type:  Identity )
# 263/377: Analysing op name: conv_dw_1_bn/moving_variance ( type:  Const )
# 264/377: Analysing op name: conv_dw_1_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 265/377: Analysing op name: conv_dw_1_bn/moving_mean ( type:  Const )
# 266/377: Analysing op name: conv_dw_1_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 267/377: Analysing op name: conv_dw_1_bn/beta ( type:  Const )
# 268/377: Analysing op name: conv_dw_1_bn/ReadVariableOp_1 ( type:  Identity )
# 269/377: Analysing op name: conv_dw_1_bn/gamma ( type:  Const )
# 270/377: Analysing op name: conv_dw_1_bn/ReadVariableOp ( type:  Identity )
# 271/377: Analysing op name: conv_dw_1/depthwise_kernel ( type:  Const )
# 272/377: Analysing op name: conv_dw_1/depthwise/ReadVariableOp ( type:  Identity )
# 273/377: Analysing op name: conv1_bn/moving_variance ( type:  Const )
# 274/377: Analysing op name: conv1_bn/FusedBatchNorm/ReadVariableOp_1 ( type:  Identity )
# 275/377: Analysing op name: conv1_bn/moving_mean ( type:  Const )
# 276/377: Analysing op name: conv1_bn/FusedBatchNorm/ReadVariableOp ( type:  Identity )
# 277/377: Analysing op name: conv1_bn/beta ( type:  Const )
# 278/377: Analysing op name: conv1_bn/ReadVariableOp_1 ( type:  Identity )
# 279/377: Analysing op name: conv1_bn/gamma ( type:  Const )
# 280/377: Analysing op name: conv1_bn/ReadVariableOp ( type:  Identity )
# 281/377: Analysing op name: conv1/kernel ( type:  Const )
# 282/377: Analysing op name: conv1/Conv2D/ReadVariableOp ( type:  Identity )
# 283/377: Analysing op name: conv1_pad/Pad/paddings ( type:  Const )
# 284/377: Analysing op name: input_1 ( type:  Placeholder )
# Skipping name of placeholder
# 285/377: Analysing op name: conv1_pad/Pad ( type:  Pad )
# 286/377: Analysing op name: conv1/Conv2D ( type:  Conv2D )
# 287/377: Analysing op name: conv1_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 288/377: Analysing op name: conv1_relu/Relu6 ( type:  Relu6 )
# 289/377: Analysing op name: conv_dw_1/depthwise ( type:  DepthwiseConv2dNative )
# 290/377: Analysing op name: conv_dw_1_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 291/377: Analysing op name: conv_dw_1_relu/Relu6 ( type:  Relu6 )
# 292/377: Analysing op name: conv_pw_1/Conv2D ( type:  Conv2D )
# 293/377: Analysing op name: conv_pw_1_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 294/377: Analysing op name: conv_pw_1_relu/Relu6 ( type:  Relu6 )
# 295/377: Analysing op name: conv_pad_2/Pad ( type:  Pad )
# 296/377: Analysing op name: conv_dw_2/depthwise ( type:  DepthwiseConv2dNative )
# 297/377: Analysing op name: conv_dw_2_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 298/377: Analysing op name: conv_dw_2_relu/Relu6 ( type:  Relu6 )
# 299/377: Analysing op name: conv_pw_2/Conv2D ( type:  Conv2D )
# 300/377: Analysing op name: conv_pw_2_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 301/377: Analysing op name: conv_pw_2_relu/Relu6 ( type:  Relu6 )
# 302/377: Analysing op name: conv_dw_3/depthwise ( type:  DepthwiseConv2dNative )
# 303/377: Analysing op name: conv_dw_3_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 304/377: Analysing op name: conv_dw_3_relu/Relu6 ( type:  Relu6 )
# 305/377: Analysing op name: conv_pw_3/Conv2D ( type:  Conv2D )
# 306/377: Analysing op name: conv_pw_3_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 307/377: Analysing op name: conv_pw_3_relu/Relu6 ( type:  Relu6 )
# 308/377: Analysing op name: conv_pad_4/Pad ( type:  Pad )
# 309/377: Analysing op name: conv_dw_4/depthwise ( type:  DepthwiseConv2dNative )
# 310/377: Analysing op name: conv_dw_4_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 311/377: Analysing op name: conv_dw_4_relu/Relu6 ( type:  Relu6 )
# 312/377: Analysing op name: conv_pw_4/Conv2D ( type:  Conv2D )
# 313/377: Analysing op name: conv_pw_4_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 314/377: Analysing op name: conv_pw_4_relu/Relu6 ( type:  Relu6 )
# 315/377: Analysing op name: conv_dw_5/depthwise ( type:  DepthwiseConv2dNative )
# 316/377: Analysing op name: conv_dw_5_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 317/377: Analysing op name: conv_dw_5_relu/Relu6 ( type:  Relu6 )
# 318/377: Analysing op name: conv_pw_5/Conv2D ( type:  Conv2D )
# 319/377: Analysing op name: conv_pw_5_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 320/377: Analysing op name: conv_pw_5_relu/Relu6 ( type:  Relu6 )
# 321/377: Analysing op name: conv_pad_6/Pad ( type:  Pad )
# 322/377: Analysing op name: conv_dw_6/depthwise ( type:  DepthwiseConv2dNative )
# 323/377: Analysing op name: conv_dw_6_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 324/377: Analysing op name: conv_dw_6_relu/Relu6 ( type:  Relu6 )
# 325/377: Analysing op name: conv_pw_6/Conv2D ( type:  Conv2D )
# 326/377: Analysing op name: conv_pw_6_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 327/377: Analysing op name: conv_pw_6_relu/Relu6 ( type:  Relu6 )
# 328/377: Analysing op name: conv_dw_7/depthwise ( type:  DepthwiseConv2dNative )
# 329/377: Analysing op name: conv_dw_7_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 330/377: Analysing op name: conv_dw_7_relu/Relu6 ( type:  Relu6 )
# 331/377: Analysing op name: conv_pw_7/Conv2D ( type:  Conv2D )
# 332/377: Analysing op name: conv_pw_7_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 333/377: Analysing op name: conv_pw_7_relu/Relu6 ( type:  Relu6 )
# 334/377: Analysing op name: conv_dw_8/depthwise ( type:  DepthwiseConv2dNative )
# 335/377: Analysing op name: conv_dw_8_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 336/377: Analysing op name: conv_dw_8_relu/Relu6 ( type:  Relu6 )
# 337/377: Analysing op name: conv_pw_8/Conv2D ( type:  Conv2D )
# 338/377: Analysing op name: conv_pw_8_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 339/377: Analysing op name: conv_pw_8_relu/Relu6 ( type:  Relu6 )
# 340/377: Analysing op name: conv_dw_9/depthwise ( type:  DepthwiseConv2dNative )
# 341/377: Analysing op name: conv_dw_9_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 342/377: Analysing op name: conv_dw_9_relu/Relu6 ( type:  Relu6 )
# 343/377: Analysing op name: conv_pw_9/Conv2D ( type:  Conv2D )
# 344/377: Analysing op name: conv_pw_9_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 345/377: Analysing op name: conv_pw_9_relu/Relu6 ( type:  Relu6 )
# 346/377: Analysing op name: conv_dw_10/depthwise ( type:  DepthwiseConv2dNative )
# 347/377: Analysing op name: conv_dw_10_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 348/377: Analysing op name: conv_dw_10_relu/Relu6 ( type:  Relu6 )
# 349/377: Analysing op name: conv_pw_10/Conv2D ( type:  Conv2D )
# 350/377: Analysing op name: conv_pw_10_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 351/377: Analysing op name: conv_pw_10_relu/Relu6 ( type:  Relu6 )
# 352/377: Analysing op name: conv_dw_11/depthwise ( type:  DepthwiseConv2dNative )
# 353/377: Analysing op name: conv_dw_11_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 354/377: Analysing op name: conv_dw_11_relu/Relu6 ( type:  Relu6 )
# 355/377: Analysing op name: conv_pw_11/Conv2D ( type:  Conv2D )
# 356/377: Analysing op name: conv_pw_11_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 357/377: Analysing op name: conv_pw_11_relu/Relu6 ( type:  Relu6 )
# 358/377: Analysing op name: conv_pad_12/Pad ( type:  Pad )
# 359/377: Analysing op name: conv_dw_12/depthwise ( type:  DepthwiseConv2dNative )
# 360/377: Analysing op name: conv_dw_12_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 361/377: Analysing op name: conv_dw_12_relu/Relu6 ( type:  Relu6 )
# 362/377: Analysing op name: conv_pw_12/Conv2D ( type:  Conv2D )
# 363/377: Analysing op name: conv_pw_12_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 364/377: Analysing op name: conv_pw_12_relu/Relu6 ( type:  Relu6 )
# 365/377: Analysing op name: conv_dw_13/depthwise ( type:  DepthwiseConv2dNative )
# 366/377: Analysing op name: conv_dw_13_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 367/377: Analysing op name: conv_dw_13_relu/Relu6 ( type:  Relu6 )
# 368/377: Analysing op name: conv_pw_13/Conv2D ( type:  Conv2D )
# 369/377: Analysing op name: conv_pw_13_bn/FusedBatchNorm ( type:  FusedBatchNorm )
# 370/377: Analysing op name: conv_pw_13_relu/Relu6 ( type:  Relu6 )
# 371/377: Analysing op name: reshape/Shape ( type:  Shape )
# 372/377: Analysing op name: reshape/strided_slice ( type:  StridedSlice )
# 373/377: Analysing op name: reshape/Reshape/shape ( type:  Pack )
# 374/377: Analysing op name: reshape/Reshape ( type:  Reshape )
# 375/377: Analysing op name: dense/MatMul ( type:  MatMul )
# 376/377: Analysing op name: dense/BiasAdd ( type:  BiasAdd )
# 377/377: Analysing op name: dense/Softmax ( type:  Softmax )
# Translation to CoreML spec completed. Now compiling and saving the CoreML model.
#
#  Core ML model generated. Saved at location: mobilenet.mlmodel
#
# Core ML input(s):
#  [name: "input_1__0"
# type {
#   imageType {
#     width: 48
#     height: 48
#     colorSpace: GRAYSCALE
#   }
# }
# ]
# Core ML output(s):
#  [name: "dense__Softmax__0"
# type {
#   dictionaryType {
#     stringKeyType {
#     }
#   }
# }
# , name: "classLabel"
# type {
#   stringType {
#   }
# }
# ]
# input {
#   name: "input_1__0"
#   type {
#     imageType {
#       width: 48
#       height: 48
#       colorSpace: GRAYSCALE
#     }
#   }
# }
# output {
#   name: "dense__Softmax__0"
#   type {
#     dictionaryType {
#       stringKeyType {
#       }
#     }
#   }
# }
# output {
#   name: "classLabel"
#   type {
#     stringType {
#     }
#   }
# }
# predictedFeatureName: "classLabel"
# predictedProbabilitiesName: "dense__Softmax__0"

# %% [markdown]
# ## Convert to TFLite

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
## Or from a SavedModel
# converter = tf.lite.TFLiteConverter('./saved_model')

tflite_model = converter.convert()
open("result.tflite", "wb").write(tflite_model)
# Out:
# 12784696

# %% [markdown]
# ## Convert to TFJS

# %%
# Convert in the current environment
import sys
# !tensorflowjs_converter --input_format=tf_saved_model saved_model my-tfjs --output_format tfjs_graph_model
